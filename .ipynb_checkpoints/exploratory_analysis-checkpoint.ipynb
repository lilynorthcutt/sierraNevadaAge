# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## CSV File

# %%
import pandas as pd

# %%
file_path = "Data/attia_CentralSierraCretaceousIntrusionsGeochronologyData_forLily12082023.xlsx"

df_raw = pd.read_excel(file_path, sheet_name =  'CentralSierraNevada Rock Ages')

# %%
df_raw.head()
# Out:
#   AnalysisName OriginalName    Age  Uncertainty            Reference Mineral  \
# 0     EL16-525          NaN   96.1          0.8  Ardill et al., 2018  Zircon
# 1     HH16-522          NaN   96.4          1.1  Ardill et al., 2018  Zircon
# 2        TIOGA          NaN  101.0          1.5  Ardill et al., 2018  Zircon
# 3         GP-2          NaN  102.2          1.0  Ardill et al., 2018  Zircon
# 4      IMP39-A          NaN  104.2          1.2  Ardill et al., 2018  Zircon
#
#           Method  RockType                          Lithology  \
# 0  spot analyses  Plutonic                       granodiorite
# 1  spot analyses  Plutonic           porphyritic granodiorite
# 2  spot analyses  Plutonic                       monzodiorite
# 3  spot analyses  Plutonic                       granodiorite
# 4  spot analyses  Plutonic  Grizzly Peak porphyritic tonalite
#
#                                       Unit                              Group  \
# 0                 Ellery Lake granodiorite             unassigned, Tioga Pass
# 1  porphyritic granodiorite of Lake Vernon   Jack Main Canyon intrusive suite
# 2                  Tioga Lake monzodiorite      Tioga Pass hypabyssal complex
# 3             Illouette Creek granodiorite  Buena Vista Crest intrusive suite
# 4            granodiorite of Grizzly Creek     unassigned, Iron Mountain area
#
#   Easting Northing      Datum DataComment
# 0  304057  4200841  NAD27 11S         NaN
# 1  258103  4209586  NAD27 11S         NaN
# 2  301629  4200112  NAD27 11S         NaN
# 3  269559  4172071  NAD27 11S         NaN
# 4  278808  4149668  NAD27 11S         NaN

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AnalysisName  217 non-null    object
#  1   OriginalName  170 non-null    object
#  2   Age           217 non-null    float64
#  3   Uncertainty   217 non-null    float64
#  4   Reference     217 non-null    object
#  5   Mineral       217 non-null    object
#  6   Method        217 non-null    object
#  7   RockType      217 non-null    object
#  8   Lithology     217 non-null    object
#  9   Unit          217 non-null    object
#  10  Group         217 non-null    object
#  11  Easting       217 non-null    object
#  12  Northing      217 non-null    object
#  13  Datum         213 non-null    object
#  14  DataComment   70 non-null     object
# dtypes: float64(2), object(13)
# memory usage: 25.6+ KB

# %%
df_raw.describe() #NOTE: easting and northing read in as strings b/c "NA*"
# Out:
#               Age  Uncertainty
# count  217.000000   217.000000
# mean    99.905253     2.899585
# std     10.255814     3.848287
# min     83.500000     0.040000
# 25%     91.450000     0.400000
# 50%     97.000000     1.100000
# 75%    106.300000     2.500000
# max    124.200000    12.000000

# %% [markdown]
# ## Data Cleaning
# Before we dive into visualizing the data, let's first clean it and handle missing data.

# %%
# Columns with missing data
df_raw.isnull().sum()
# Out:
# AnalysisName      0
# OriginalName     47
# Age               0
# Uncertainty       0
# Reference         0
# Mineral           0
# Method            0
# RockType          0
# Lithology         0
# Unit              0
# Group             0
# Easting           0
# Northing          0
# Datum             4
# DataComment     147
# dtype: int64

# %% [markdown]
# The five columns with missing data are as follows:
# - __OriginalName:__ If OriginalName col is empty, then the OriginalName is the same as AnalysisName
# - __Easting:__ _(Not shown above)_ manual entries "NA*" input for missing values
#     - Not much can be done to get exact location, may use for some testing:
#         Predict age of entire area covered in paper, and take avgs => check if this avg age is similar to the age
#         given)
# - __Northing:__ _(Not shown above)_ manual entries "NA*" input for missing values
#     - Same note as above
# - __Datum:__ Missing for values we do not have a location -> nothing to be done to resolve
# - __DataComment:__ Not all rows need comments, acceptable to be NA, however will be creating boolean cols based on the notes further on in the notebook.
#
# After resolving issues with missing data, we will separate the rows missing necessary features (easting and northing) into a separate dataframe

# %%
df_raw['OriginalName'] = df_raw['OriginalName'].fillna(df_raw['AnalysisName'])
df_raw['Easting'] = pd.to_numeric(df_raw['Easting'].replace('NA*', pd.NA), errors = 'coerce')
df_raw['Northing'] = pd.to_numeric(df_raw['Northing'].replace('NA*', pd.NA), errors = 'coerce')
df_raw.isnull().sum()
# Out:
# AnalysisName      0
# OriginalName      0
# Age               0
# Uncertainty       0
# Reference         0
# Mineral           0
# Method            0
# RockType          0
# Lithology         0
# Unit              0
# Group             0
# Easting           4
# Northing          4
# Datum             4
# DataComment     147
# dtype: int64

# %%
invalid_df = df_raw[pd.isna(df_raw['Easting']) | pd.isna(df_raw['Northing'])].copy()
df = df_raw[pd.notna(df_raw['Easting']) & pd.notna(df_raw['Northing'])].copy()

print(f'Raw data size: {df_raw.shape} \nUsable data size: {df.shape} \nMissing location size {invalid_df.shape}')
# Out:
# Raw data size: (217, 15)
# Usable data size: (213, 15)
# Missing location size (4, 15)

# %%
df.duplicated() #no duplicates
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 212    False
# 213    False
# 214    False
# 215    False
# 216    False
# Length: 213, dtype: bool

# %% [markdown]
# ## Feature Engineering
# Let's __summarize the DataComments__ column with additional columns to help us represent issues or inconsistencies present within the data.
#
# We will also add additional columns such as __year published__, __longitude__, __latitude__, etc.

# %%
# Summarize data column by adding: estimated location, and estimated uncertainty
location_estim_list = ["location not given", "location is a total guess", "approximate location"]
pattern = '|'.join(location_estim_list)
df['locationEstimated'] = df['DataComment'].str.contains(pattern, case = False, na = False)

df['uncertaintyEstimated'] = df['DataComment'].str.contains('no error given', case = False, na = False)
# df[df['uncertaintyEstimated'] == True]

# %%
# Add year published column, if not published make it current year
df['year'] = df['Reference'].str.extract(r'(\d+)', expand = False).fillna(2023).astype(int)
#df[['Reference', 'year']]

# %%
#!pip install utm

# %%
# Add lat and long
import utm
lat, long = utm.to_latlon(df['Easting'], df['Northing'], 11, 'S')
df['lat'] = lat
df['long'] = long

# %% [markdown]
# ## Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/lilynorthcutt/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
import matplotlib.pyplot as plt
plt.scatter(x=df['long'], y=df['lat'])
plt.show()

# %% [markdown]
# ## Shapefile Data

# %%
#!pip install geopandas

# %%
import os
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
def read_shapefiles_in_folder(folder_path):
    shapefiles_dict = {}

    # Check if the folder path exists
    if not os.path.exists(folder_path):
        raise FileNotFoundError(f"The folder '{folder_path}' does not exist.")

    # Iterate through files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".shp"):
            file_path = os.path.join(folder_path, filename)

            # Extract file name without extension
            file_name = os.path.splitext(filename)[0]

            # Read shapefile into GeoDataFrame
            gdf = gpd.read_file(file_path)

            # Store GeoDataFrame in the dictionary
            shapefiles_dict[file_name] = gdf

    return shapefiles_dict

# %%
folder_path = 'Data/CentralSierraMapData_ForLily20231220'

try:
    # Read shapefiles into a dictionary
    shapefiles_data = read_shapefiles_in_folder(folder_path)

    # Access GeoDataFrames by file name
    for file_name, gdf in shapefiles_data.items():
        print(f"File Name: {file_name}")
        #print(gdf.head())  # Display the first few rows of the GeoDataFrame

except FileNotFoundError as e:
    print(e)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File Name: CretaceousIntrusionsIndividualPolygons
# File Name: CretaceousIntrusionsExtentPolygons
# File Name: DetailedMapDataAreaBoundaryLine
# File Name: IntrusiveSuitePolygons

# %%
# Coordinate reference system
gdf.crs
# Out:
# <Projected CRS: EPSG:26711>
# Name: NAD27 / UTM zone 11N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: North America - between 120°W and 114°W - onshore. Canada - Alberta; British Columbia; Northwest Territories; Nunavut. Mexico. United States (USA) - California; Idaho; Nevada; Oregon; Washington.
# - bounds: (-120.0, 26.93, -114.0, 78.13)
# Coordinate Operation:
# - name: UTM zone 11N
# - method: Transverse Mercator
# Datum: North American Datum 1927
# - Ellipsoid: Clarke 1866
# - Prime Meridian: Greenwich

# %%
# Plot the files individually
fig, axes = plt.subplots(nrows=1, ncols=len(shapefiles_data), figsize=(15, 5))

for i, (file_name, gdf) in enumerate(shapefiles_data.items()):
    gdf.plot(ax=axes[i], alpha=0.5, edgecolor='k')
    axes[i].set_title(file_name)

plt.show()

# %%
# Plot them together
fig, ax = plt.subplots(figsize=(10, 10))

for file_name, gdf in shapefiles_data.items():
    # Plot each GeoDataFrame on the same axis
    gdf.plot(ax=ax, alpha=0.5, edgecolor='k', label=file_name)

# Add legend
ax.legend()

# Show the plot
plt.show()
# Out:
# <ipython-input-31-f326944ee257>:9: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend()

# %% [markdown]
# ### Attributes of the shapefiles
#
# We are reading in 4 different shapefiles:
# - __Detailed Map Data Area Boundary Line -__ boundary of area
#
# - __Cretaceous Intrusions Individual Polygons -__ detailed shapefile that has all individually mapped units of Cretaceous intrusions
#
# - __Cretaceous Intrusions Extent Polygons -__ combined units from indiv polygon file s.t. any area of contiguous mapped Cretaceous intrusions becomes a single polygon
#
# - __Intrusive Suite Polygons -__ combined units from indiv polygon file s.t.any area of contiguous mapped Cretacoues intrusions that belong to the same intrusive suite becomes a single polygon

# %%
# Number of shapes in each

for file, gdf in shapefiles_data.items():
    print(f"File: {file}   Number of shapes: {len(gdf)}")
# Out:
# File: CretaceousIntrusionsIndividualPolygons   Number of shapes: 1435
# File: CretaceousIntrusionsExtentPolygons   Number of shapes: 189
# File: DetailedMapDataAreaBoundaryLine   Number of shapes: 1
# File: IntrusiveSuitePolygons   Number of shapes: 625

# %% [markdown]
# Notes: _extent_ is "more aggressive" at combining than _suite_ as it resulted in fewer shapes

# %%
shapefiles_data["CretaceousIntrusionsIndividualPolygons"]
# Out:
#      Age Label                              Unit  \
# 0     eK    bl                         Bass Lake
# 1     eK    bl        mafic microtonalite facies
# 2     eK    bl              microtonalite facies
# 3     eK    sp  Shuteye Peak quartz monzodiorite
# 4     KJ    mu                              None
# ...   ..   ...                               ...
# 1430  KJ    mu                              None
# 1431  KJ    mu                              None
# 1432  KJ    mu                              None
# 1433  KJ    mu                              None
# 1434  KJ    mu                              None
#
#                               Grouping                    IntSuite   RockType  \
# 0                   Bass Lake Tonalite   Fine Gold Intrusive Suite  Intrusive
# 1                   Bass Lake Tonalite   Fine Gold Intrusive Suite  Intrusive
# 2                   Bass Lake Tonalite   Fine Gold Intrusive Suite  Intrusive
# 3     Shuteye Peak quartz monzodiorite      Shaver Intrusive Suite  Intrusive
# 4           undivided mafic intrusions                  unassigned  Intrusive
# ...                                ...                         ...        ...
# 1430        undivided mafic intrusions  Fine Gold Intrusive Suite?  Intrusive
# 1431        undivided mafic intrusions  Fine Gold Intrusive Suite?  Intrusive
# 1432        undivided mafic intrusions  Fine Gold Intrusive Suite?  Intrusive
# 1433        undivided mafic intrusions  Fine Gold Intrusive Suite?  Intrusive
# 1434        undivided mafic intrusions  Fine Gold Intrusive Suite?  Intrusive
#
#        Subtype Comment    Shape_Leng    Shape_Area  \
# 0     Plutonic    None    739.795946  3.414064e+04
# 1     Plutonic    None  19711.170758  1.307741e+07
# 2     Plutonic    None    807.122023  3.888118e+04
# 3     Plutonic    None    513.312351  1.284494e+04
# 4     Plutonic    None    790.624141  2.507926e+04
# ...        ...     ...           ...           ...
# 1430  Plutonic    None    478.124033  1.625629e+04
# 1431  Plutonic    None    463.488336  1.614586e+04
# 1432  Plutonic    None    215.199952  3.021826e+03
# 1433  Plutonic    None   2712.359154  3.353513e+05
# 1434  Plutonic    None   5318.164680  4.934410e+05
#
#                                                geometry
# 0     POLYGON ((257426.387 4136499.165, 257456.020 4...
# 1     POLYGON ((246084.099 4139789.471, 246140.588 4...
# 2     POLYGON ((254464.989 4140241.081, 254478.879 4...
# 3     POLYGON ((277907.294 4140447.286, 277914.173 4...
# 4     POLYGON ((234210.305 4140536.455, 234204.735 4...
# ...                                                 ...
# 1430  POLYGON ((251831.437 4147144.682, 251817.547 4...
# 1431  POLYGON ((262159.713 4153324.617, 262174.001 4...
# 1432  POLYGON ((265543.506 4153675.539, 265539.316 4...
# 1433  POLYGON ((251364.397 4152885.820, 251339.451 4...
# 1434  POLYGON ((256472.103 4154210.010, 256418.525 4...
#
# [1435 rows x 11 columns]

# %%
shapefiles_data["CretaceousIntrusionsExtentPolygons"]
# Out:
#       RockType    Shape_Leng    Shape_Area CreatedBy  CreateDate LastEditor  \
# 0    Intrusive  2.521207e+02  3.873971e+03     Attia  2023-12-20      Attia
# 1    Intrusive  1.347295e+04  8.805815e+06     Attia  2023-12-20      Attia
# 2    Intrusive  5.011541e+02  1.830240e+04     Attia  2023-12-20      Attia
# 3    Intrusive  3.892306e+02  9.551895e+03     Attia  2023-12-20      Attia
# 4    Intrusive  1.161742e+03  1.655245e+04     Attia  2023-12-20      Attia
# ..         ...           ...           ...       ...         ...        ...
# 184  Intrusive  1.128577e+03  3.431452e+04     Attia  2023-12-20      Attia
# 185  Intrusive  2.200742e+04  1.239579e+07     Attia  2023-12-20      Attia
# 186  Intrusive  1.168315e+03  6.954252e+04     Attia  2023-12-20      Attia
# 187  Intrusive  1.733900e+03  2.392192e+04     Attia  2023-12-20      Attia
# 188  Intrusive  1.554737e+06  5.841673e+09     Attia  2023-12-20      Attia
#
#        EditDate                                           geometry
# 0    2023-12-20  POLYGON ((238115.504 4134618.088, 238104.164 4...
# 1    2023-12-20  POLYGON ((237783.198 4134409.419, 237790.474 4...
# 2    2023-12-20  POLYGON ((249728.059 4135433.846, 249716.946 4...
# 3    2023-12-20  POLYGON ((236789.107 4135487.757, 236771.512 4...
# 4    2023-12-20  POLYGON ((238676.433 4135774.590, 238627.750 4...
# ..          ...                                                ...
# 184  2023-12-20  POLYGON ((274401.891 4231955.644, 274472.006 4...
# 185  2023-12-20  POLYGON ((296027.617 4230631.795, 296009.625 4...
# 186  2023-12-20  POLYGON ((294166.182 4232460.644, 294172.796 4...
# 187  2023-12-20  POLYGON ((293405.503 4233124.220, 293365.815 4...
# 188  2023-12-20  POLYGON ((310121.213 4174826.290, 310088.774 4...
#
# [189 rows x 8 columns]

# %%
shapefiles_data["IntrusiveSuitePolygons"]
# Out:
#                              IntSuite    Shape_Leng    Shape_Area  \
# 0    Jack Main Canyon intrusive suite   1705.180909  1.211059e+05
# 1    Jack Main Canyon intrusive suite  85088.316849  2.039799e+08
# 2    Jack Main Canyon intrusive suite   8819.246797  1.985350e+06
# 3           John Muir Intrusive Suite  30820.887260  5.461314e+07
# 4           John Muir Intrusive Suite    652.394992  1.207175e+04
# ..                                ...           ...           ...
# 620                        unassigned  22007.421342  1.239579e+07
# 621                        unassigned   1168.314686  6.954252e+04
# 622                        unassigned   1733.900103  2.392192e+04
# 623                        unassigned  20434.400287  6.541468e+06
# 624                        unassigned  68928.142280  1.092079e+08
#
#                                               geometry
# 0    POLYGON ((263061.105 4214338.169, 263039.674 4...
# 1    POLYGON ((257224.523 4224282.341, 257233.255 4...
# 2    POLYGON ((259332.361 4227115.885, 259370.688 4...
# 3    POLYGON ((314841.854 4154646.874, 314879.857 4...
# 4    POLYGON ((313539.771 4169434.923, 313535.628 4...
# ..                                                 ...
# 620  POLYGON ((296027.617 4230631.795, 296009.625 4...
# 621  POLYGON ((294166.182 4232460.644, 294172.796 4...
# 622  POLYGON ((293405.503 4233124.220, 293365.815 4...
# 623  POLYGON ((281169.701 4234218.656, 281080.121 4...
# 624  POLYGON ((255424.908 4231236.794, 255455.864 4...
#
# [625 rows x 4 columns]

# %% [markdown]
# ### Individual polygons
#
# Lets take a look at CretaceousIntrusionsIndividualPolygons, as it has the most information

# %%
shapefiles_data["CretaceousIntrusionsIndividualPolygons"]
# Out:
#      Age Label                              Unit  \
# 0     eK    bl                         Bass Lake
# 1     eK    bl        mafic microtonalite facies
# 2     eK    bl              microtonalite facies
# 3     eK    sp  Shuteye Peak quartz monzodiorite
# 4     KJ    mu                              None
# ...   ..   ...                               ...
# 1430  KJ    mu                              None
# 1431  KJ    mu                              None
# 1432  KJ    mu                              None
# 1433  KJ    mu                              None
# 1434  KJ    mu                              None
#
#                               Grouping                    IntSuite   RockType  \
# 0                   Bass Lake Tonalite   Fine Gold Intrusive Suite  Intrusive
# 1                   Bass Lake Tonalite   Fine Gold Intrusive Suite  Intrusive
# 2                   Bass Lake Tonalite   Fine Gold Intrusive Suite  Intrusive
# 3     Shuteye Peak quartz monzodiorite      Shaver Intrusive Suite  Intrusive
# 4           undivided mafic intrusions                  unassigned  Intrusive
# ...                                ...                         ...        ...
# 1430        undivided mafic intrusions  Fine Gold Intrusive Suite?  Intrusive
# 1431        undivided mafic intrusions  Fine Gold Intrusive Suite?  Intrusive
# 1432        undivided mafic intrusions  Fine Gold Intrusive Suite?  Intrusive
# 1433        undivided mafic intrusions  Fine Gold Intrusive Suite?  Intrusive
# 1434        undivided mafic intrusions  Fine Gold Intrusive Suite?  Intrusive
#
#        Subtype Comment    Shape_Leng    Shape_Area  \
# 0     Plutonic    None    739.795946  3.414064e+04
# 1     Plutonic    None  19711.170758  1.307741e+07
# 2     Plutonic    None    807.122023  3.888118e+04
# 3     Plutonic    None    513.312351  1.284494e+04
# 4     Plutonic    None    790.624141  2.507926e+04
# ...        ...     ...           ...           ...
# 1430  Plutonic    None    478.124033  1.625629e+04
# 1431  Plutonic    None    463.488336  1.614586e+04
# 1432  Plutonic    None    215.199952  3.021826e+03
# 1433  Plutonic    None   2712.359154  3.353513e+05
# 1434  Plutonic    None   5318.164680  4.934410e+05
#
#                                                geometry
# 0     POLYGON ((257426.387 4136499.165, 257456.020 4...
# 1     POLYGON ((246084.099 4139789.471, 246140.588 4...
# 2     POLYGON ((254464.989 4140241.081, 254478.879 4...
# 3     POLYGON ((277907.294 4140447.286, 277914.173 4...
# 4     POLYGON ((234210.305 4140536.455, 234204.735 4...
# ...                                                 ...
# 1430  POLYGON ((251831.437 4147144.682, 251817.547 4...
# 1431  POLYGON ((262159.713 4153324.617, 262174.001 4...
# 1432  POLYGON ((265543.506 4153675.539, 265539.316 4...
# 1433  POLYGON ((251364.397 4152885.820, 251339.451 4...
# 1434  POLYGON ((256472.103 4154210.010, 256418.525 4...
#
# [1435 rows x 11 columns]

# %%
gdf = shapefiles_data["CretaceousIntrusionsIndividualPolygons"]

for column in gdf.columns:
    print(f'Column {column}: {gdf[column].nunique()} unique vals')
# Out:
# Column Age: 5 unique vals
# Column Label: 69 unique vals
# Column Unit: 210 unique vals
# Column Grouping: 87 unique vals
# Column IntSuite: 26 unique vals
# Column RockType: 1 unique vals
# Column Subtype: 5 unique vals
# Column Comment: 38 unique vals
# Column Shape_Leng: 1435 unique vals
# Column Shape_Area: 1435 unique vals
# Column geometry: 1435 unique vals

# %%
# Plot the files individually
legend_criteria = "IntSuite"

ax = gdf.plot(figsize=(10, 10), alpha=0.5, edgecolor='k',column=legend_criteria, cmap='viridis', legend=True)

legend = ax.get_legend()
legend.set_bbox_to_anchor((1.75, 1))
legend.set_title(legend_criteria)


ax.set_title(f'Individual Polygons')
plt.show()

# %%
# Plot the files individually
legend_criteria = "Age"

ax = gdf.plot(figsize=(10, 10), alpha=0.5, edgecolor='k',column=legend_criteria, cmap='viridis', legend=True)

legend = ax.get_legend()
legend.set_bbox_to_anchor((1.75, 1))
legend.set_title(legend_criteria)


ax.set_title(f'Individual Polygons')
plt.show()

# %%
# Look at Difference between Extent vs. Suite
gdf_detailed = shapefiles_data["CretaceousIntrusionsIndividualPolygons"]
gdf_extent = shapefiles_data["CretaceousIntrusionsExtentPolygons"]
gdf_suite = shapefiles_data["IntrusiveSuitePolygons"]


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 10))
color_column = "Age"

axes[0].set_title('Individual Polygons with Extent Boundaries')
gdf_detailed.plot(ax=axes[0], alpha=0.5, edgecolor='k')
gdf_extent.boundary.plot(ax=axes[0], color='red', linewidth=2) 

axes[1].set_title('Individual Polygons with Suite Boundaries')
gdf_detailed.plot(ax=axes[1], alpha=0.5, edgecolor='k')
gdf_suite.boundary.plot(ax=axes[1], color='Blue', linewidth=2) 

plt.show()

# %% [markdown]
# # Putting them together
#
# Adding ages ontop of the shapefiles

# %%
df
# Out:
#     AnalysisName OriginalName    Age  Uncertainty             Reference  \
# 0       EL16-525     EL16-525   96.1          0.8   Ardill et al., 2018
# 1       HH16-522     HH16-522   96.4          1.1   Ardill et al., 2018
# 2          TIOGA        TIOGA  101.0          1.5   Ardill et al., 2018
# 3           GP-2         GP-2  102.2          1.0   Ardill et al., 2018
# 4        IMP39-A      IMP39-A  104.2          1.2   Ardill et al., 2018
# ..           ...          ...    ...          ...                   ...
# 212      Tea95-4            4   95.0          1.0  Tobisch et al., 1995
# 213      Tea95-3            3   99.0          1.0  Tobisch et al., 1995
# 214        F85-2        F85-2  102.0          2.0  Tobisch et al., 2000
# 215          VM6          VM6  100.0          1.0    Tomek et al., 2016
# 216         FT16         FT16  101.0          1.0    Tomek et al., 2016
#
#     Mineral                    Method    RockType  \
# 0    Zircon             spot analyses    Plutonic
# 1    Zircon             spot analyses    Plutonic
# 2    Zircon             spot analyses    Plutonic
# 3    Zircon             spot analyses    Plutonic
# 4    Zircon             spot analyses    Plutonic
# ..      ...                       ...         ...
# 212  Zircon  TIMS multigrain fraction    Plutonic
# 213  Zircon  TIMS multigrain fraction    Plutonic
# 214  Zircon  TIMS multigrain fraction  Hypabyssal
# 215  Zircon             spot analyses    Plutonic
# 216  Zircon             spot analyses    Plutonic
#
#                              Lithology  \
# 0                         granodiorite
# 1             porphyritic granodiorite
# 2                         monzodiorite
# 3                         granodiorite
# 4    Grizzly Peak porphyritic tonalite
# ..                                 ...
# 212        Red Devil Lake granodiorite
# 213          Illilouette Creek granite
# 214                        felsic dike
# 215                            granite
# 216                            granite
#
#                                         Unit  \
# 0                   Ellery Lake granodiorite
# 1    porphyritic granodiorite of Lake Vernon
# 2                    Tioga Lake monzodiorite
# 3               Illouette Creek granodiorite
# 4              granodiorite of Grizzly Creek
# ..                                       ...
# 212                                     WLIS
# 213                                    BVCIS
# 214                          hypabyssal dike
# 215                     Shellenbarger pluton
# 216                     Shellenbarger pluton
#
#                                           Group   Easting   Northing  \
# 0                        unassigned, Tioga Pass  304057.0  4200841.0
# 1              Jack Main Canyon intrusive suite  258103.0  4209586.0
# 2                 Tioga Pass hypabyssal complex  301629.0  4200112.0
# 3             Buena Vista Crest intrusive suite  269559.0  4172071.0
# 4                unassigned, Iron Mountain area  278808.0  4149668.0
# ..                                          ...       ...        ...
# 212               Washburn Lake intrusive suite  300174.0  4177056.0
# 213           Buena Vista Crest intrusive suite  280583.0  4157134.0
# 214  Ritter Range pendant hypabbysal intrusions  310708.0  4173847.0
# 215            unassigned, Ritter Range pendant  307123.0  4167252.0
# 216            unassigned, Ritter Range pendant  306563.0  4170300.0
#
#          Datum DataComment  locationEstimated  uncertaintyEstimated  year  \
# 0    NAD27 11S         NaN              False                 False  2018
# 1    NAD27 11S         NaN              False                 False  2018
# 2    NAD27 11S         NaN              False                 False  2018
# 3    NAD27 11S         NaN              False                 False  2018
# 4    NAD27 11S         NaN              False                 False  2018
# ..         ...         ...                ...                   ...   ...
# 212  NAD27 11S         NaN              False                 False  1995
# 213  NAD27 11S         NaN              False                 False  1995
# 214  NAD27 11S         NaN              False                 False  2000
# 215  NAD27 11S         NaN              False                 False  2016
# 216  NAD27 11S         NaN              False                 False  2016
#
#            lat        long
# 0    37.934039 -119.229630
# 1    38.001702 -119.754979
# 2    37.926947 -119.257038
# 3    37.666911 -119.612687
# 4    37.467449 -119.501159
# ..         ...         ...
# 212  37.718985 -119.267217
# 213  37.535105 -119.483332
# 214  37.692319 -119.146943
# 215  37.632171 -119.185834
# 216  37.659506 -119.192984
#
# [213 rows x 20 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 10))
gdf.plot(ax=ax, color='lightgray', edgecolor='black')

sc = ax.scatter(df['Easting'], df['Northing'], c=df['Age'], cmap='viridis', label = "Data Points" )
cbar = plt.colorbar(sc, ax=ax, label='Age')

ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Interactive map
#
# Create an interactive map to look more in depth
#
# Helpful tutorial: https://autogis-site.readthedocs.io/en/latest/lessons/lesson-5/interactive-maps.html

# %%
#shapefiles_data["DetailedMapDataAreaBoundaryLine_LL"] = shapefiles_data["DetailedMapDataAreaBoundaryLine"].to_crs('epsg:4482')

# %%
#!pip install folium

# %%
import folium
#Tile options: https://leaflet-extras.github.io/leaflet-providers/preview/

tileOptions = ["Stadia.StamenTerrain", "OpenTopoMap", "Stadia.AlidadeSmooth",
              "Esri.WorldImagery"]

interactive_map = folium.Map(
    location= (37.75, -119.8),
    zoom_start=11,
    control_scale=True,
    tiles=tileOptions[3]
)

interactive_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c88c96bb5f333416657b5a32dab7200c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c88c96bb5f333416657b5a32dab7200c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c88c96bb5f333416657b5a32dab7200c = L.map(
#                 &quot;map_c88c96bb5f333416657b5a32dab7200c&quot;,
#                 {
#                     center: [37.75, -119.8],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c88c96bb5f333416657b5a32dab7200c);
#
#
#
#
#
#             var tile_layer_06c7d216bca5fecda33885226e44b5b9 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_06c7d216bca5fecda33885226e44b5b9.addTo(map_c88c96bb5f333416657b5a32dab7200c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Add polygon layer (folium.Choropleth)

# First add IDs for each polygon in each 
(shapefiles_data["DetailedMapDataAreaBoundaryLine"])["id"] = shapefiles_data["DetailedMapDataAreaBoundaryLine"].index.astype(str)
(shapefiles_data["CretaceousIntrusionsIndividualPolygons"])["id"] = shapefiles_data["CretaceousIntrusionsIndividualPolygons"].index.astype(str)
(shapefiles_data["CretaceousIntrusionsExtentPolygons"])["id"] = shapefiles_data["CretaceousIntrusionsExtentPolygons"].index.astype(str)
(shapefiles_data["IntrusiveSuitePolygons"])["id"] = shapefiles_data["IntrusiveSuitePolygons"].index.astype(str)


# Add a layer to interactive map
tileOptions = ["Stadia.StamenTerrain", "OpenTopoMap", "Stadia.AlidadeSmooth",
              "Esri.WorldImagery"]

interactive_map = folium.Map(
    location=(37.75, -119.8),
    zoom_start=9.25,
    control_scale=True,
    tiles=tileOptions[0]
)

boundary_layer = folium.Choropleth(
    geo_data=shapefiles_data["DetailedMapDataAreaBoundaryLine"] ,
    data=shapefiles_data["DetailedMapDataAreaBoundaryLine"] ,
    columns=('id', 'OBJECTID'),
    key_on='feature.id'
)

#shapefiles_data["CretaceousIntrusionsIndividualPolygons"]
#indivPoly_layer = folium.Choropleth(
#    geo_data=shapefiles_data["CretaceousIntrusionsIndividualPolygons"] ,
#    data=shapefiles_data["CretaceousIntrusionsIndividualPolygons"] ,
#    columns=('id', 'Age'),
#    key_on='feature.id'
#)

boundary_layer.add_to(interactive_map)

interactive_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb2ca6e43aa7539c6a906977e5fd9b6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb2ca6e43aa7539c6a906977e5fd9b6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb2ca6e43aa7539c6a906977e5fd9b6e = L.map(
#                 &quot;map_cb2ca6e43aa7539c6a906977e5fd9b6e&quot;,
#                 {
#                     center: [37.75, -119.8],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_cb2ca6e43aa7539c6a906977e5fd9b6e);
#
#
#
#
#
#             var tile_layer_d71af643ca3c275cda40b0c1901d8140 = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/stamen_terrain/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.stadiamaps.com/\&quot; target=\&quot;_blank\&quot;\u003eStadia Maps\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.stamen.com/\&quot; target=\&quot;_blank\&quot;\u003eStamen Design\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://openmaptiles.org/\&quot; target=\&quot;_blank\&quot;\u003eOpenMapTiles\u003c/a\u003e \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d71af643ca3c275cda40b0c1901d8140.addTo(map_cb2ca6e43aa7539c6a906977e5fd9b6e);
#
#
#             var choropleth_8df8e9d454974f939e3aa646c1d3bc2e = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_4dfbfcafa42d38369efb20071a1ee796_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6baed6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_4dfbfcafa42d38369efb20071a1ee796_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4dfbfcafa42d38369efb20071a1ee796 = L.geoJson(null, {
#                 onEachFeature: geo_json_4dfbfcafa42d38369efb20071a1ee796_onEachFeature,
#
#                 style: geo_json_4dfbfcafa42d38369efb20071a1ee796_styler,
#         });
#
#         function geo_json_4dfbfcafa42d38369efb20071a1ee796_add (data) {
#             geo_json_4dfbfcafa42d38369efb20071a1ee796
#                 .addData(data);
#         }
#             geo_json_4dfbfcafa42d38369efb20071a1ee796_add({&quot;bbox&quot;: [-120.78911400238947, 37.265623012207556, -119.00078486206601, 38.24997315880834], &quot;features&quot;: [{&quot;bbox&quot;: [-120.78911400238947, 37.265623012207556, -119.00078486206601, 38.24997315880834], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-119.00078486206601, 37.47117988589527], [-119.03241813873679, 37.467574362164534], [-120.17147178874188, 37.26577771056863], [-120.17163344484143, 37.26583277808778], [-120.17185674892696, 37.265923948121625], [-120.17200388616028, 37.2661372746973], [-120.17218678916365, 37.26635145556259], [-120.17246063505198, 37.26636753716777], [-120.17262540232831, 37.26642869551788], [-120.17280316049163, 37.26646155505554], [-120.17305458859136, 37.266438952488265], [-120.17331651101243, 37.26645474919724], [-120.17360228130535, 37.26647111458916], [-120.17390975568571, 37.26654521714142], [-120.17416668929792, 37.26669440780474], [-120.17435530298945, 37.266756131978575], [-120.1743955083061, 37.2669573655292], [-120.1744556357374, 37.267263976313465], [-120.17446141342215, 37.26737533854552], [-120.17596010186531, 37.26778958015857], [-120.17603609403855, 37.26775948218218], [-120.17623325718122, 37.26759252755746], [-120.17656334057344, 37.26738106056527], [-120.17690249646013, 37.26724610346823], [-120.17722198834095, 37.26711500840292], [-120.17725393194462, 37.26710190161291], [-120.17767796564169, 37.266930820200315], [-120.17794736545615, 37.26674651245753], [-120.17824274200157, 37.26650560148109], [-120.17850235306675, 37.266263839021285], [-120.17885520170748, 37.26608151871319], [-120.1792687250803, 37.26587203471489], [-120.17962405909562, 37.265623012207556], [-120.17985573963863, 37.26580973498313], [-120.18004257929772, 37.265919092947655], [-120.18036020252424, 37.26604110644431], [-120.18058245179519, 37.26616084541357], [-120.18063530312979, 37.266343304031494], [-120.18042338784817, 37.26658620773225], [-120.1800990066564, 37.2666452340696], [-120.17946429799657, 37.26670639533773], [-120.17904382744106, 37.26678220042538], [-120.17859737803047, 37.266914605904056], [-120.17823402673767, 37.26705852641821], [-120.17802743961758, 37.26715850336192], [-120.17786177690584, 37.267440653981886], [-120.17780198805409, 37.26776347773509], [-120.17767137878806, 37.26806553883411], [-120.17748435672445, 37.26828042139742], [-120.17710907697996, 37.268424054480185], [-120.17680603360314, 37.26855033839795], [-120.17645459512703, 37.26869453912322], [-120.176

# %%
shapefiles_data["CretaceousIntrusionsIndividualPolygons"].Age.unique()


## Add a column with numeric "Age" because folium is havign a hard time with it not being numeric
#https://geopandas.org/en/stable/gallery/polygon_plotting_with_folium.html
# Out:
# array(['eK', 'KJ', 'lK', 'eK?', 'lK?'], dtype=object)

# %%
File Name: CretaceousIntrusionsIndividualPolygons
File Name: CretaceousIntrusionsExtentPolygons
File Name: DetailedMapDataAreaBoundaryLine
File Name: IntrusiveSuitePolygons

# %%
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1430    1430
# 1431    1431
# 1432    1432
# 1433    1433
# 1434    1434
# Name: id, Length: 1435, dtype: object
